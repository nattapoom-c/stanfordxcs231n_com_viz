# %% [markdown]
# # Setup

# %% [markdown]
# <div style="background-color: #ffebee; border: 2px solid #d32f2f; padding: 10px; border-radius: 5px; color: #b71c1c;">
#         <b>Caution:</b> The setup code below only needs to be run once per assignment. If you've already executed it, you can safely ignore this section and proceed to the <a href="#assignment-content" style="color: #d32f2f; text-decoration: underline;">Assignment Content</a>.
#     </div>

# %% [markdown]
# This will run through setup of all necessary dependencies to complete the assignment.

# %% [markdown]
# ## Install required tools

# %%
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

if IN_COLAB:
    # fixing error like "No module named 'imp'"
    # !sed -i -e 's/from imp import reload/from importlib import reload/' /usr/local/lib/python3.12/dist-packages/IPython/extensions/autoreload.py
else:
  import os
  # add local dependencies to PATH (for uv installation)
  os.environ['PATH'] = '/usr/local/bin:$HOME/.local/bin:' + os.environ['PATH']
  # add conda dependencies to PATH (for conda installation)
  os.environ['PATH'] = '/opt/anaconda3:~/anaconda3:~:~/miniconda3:/opt/miniconda3:' + os.environ['PATH']

# %% [markdown]
# ## Install datasets

# %% [markdown]
# The code snippets below will mount your Google Drive folder (if in a Colab environment) and proceed to install the relevant datasets needed to complete the assignment.

# %%
if IN_COLAB:
    # TODO: For colab, Enter the foldername in your Google Drive
    # to the root of the assignment folder, where this notebook exists
    # e.g. 'XCS231N/XCS231N-A?/src/submission' # you need to update "A?" with the homework number
    FOLDERNAME = 'path to your submission folder, see the above description'
    WORK_DIR = '/content/drive/MyDrive/{}'.format(FOLDERNAME)
    # This mounts your Google Drive to the Colab VM.
    from google.colab import drive
    drive.mount('/content/drive')

    assert FOLDERNAME is not None, "[!] Enter the foldername."

    # Now that we've mounted your Drive, this ensures that
    # the Python interpreter of the Colab VM can load
    # python files from within it.
    import sys
    sys.path.append(WORK_DIR)
else:
    # on local or azure, FOLDERNAME is set automatically
    FOLDERNAME=os.getcwd()
    WORK_DIR = FOLDERNAME

print(f"FOLDERNAME: ", FOLDERNAME)
print(f"WORK_DIR: ", WORK_DIR)
# Out:
# FOLDERNAME:  /home/tongnatta/standford/XCS231N-A1/src/submission
# WORK_DIR:  /home/tongnatta/standford/XCS231N-A1/src/submission

# %%
print("Getting dataset: START")
# %cd $WORK_DIR/xcs231n/datasets
# !bash get_datasets.sh
# %cd $WORK_DIR
print("Getting dataset: DONE")
# Out:
# Getting dataset: START
# /home/tongnatta/standford/XCS231N-A1/src/submission/xcs231n/datasets
# /home/tongnatta/standford/XCS231N-A1/src/submission
# Getting dataset: DONE

# %% [markdown]
# # Package Manager Setup

# %% [markdown]
# Below you have the option to run through the installation of `uv` package manager. Optionally, you can still work with `conda`.

# %% [markdown]
# ## `uv` (preferred)

# %%
if not IN_COLAB:
  import os
  venv_path = os.path.normpath(os.path.join(WORK_DIR, '../..', '.venv'))
  if not os.path.isdir(venv_path):
    # %cd $WORK_DIR/../..
    # !source install.sh -r
    # !source .venv/bin/activate
  else:
    print(f".venv already exists at {venv_path}; skipping install")
# Out:
# .venv already exists at /home/tongnatta/standford/XCS231N-A1/.venv; skipping install

# %% [markdown]
# ## `conda` (legacy)

# %%
# uncomment to use conda
# if IN_COLAB:
#     !pip install -q condacolab
#     import condacolab
#     condacolab.install()
#     %cd $WORK_DIR/src
#     !conda env create -f environment.yml
#     !exec bash
# else:
#     %cd $WORK_DIR/src
#     !conda env create -f environment.yml

# %% [markdown]
# ---

# %% [markdown]
# <a id="assignment-content"></a>
#
# # Assignment Content

# %% [markdown]
# # Image features exercise
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from xcs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from xcs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'xcs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your own interest.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from xcs231n.features import *

# num_color_bins = 10 # Number of bins in the color histogram
num_color_bins = 25 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images

# %% [markdown]
# ## Train Softmax classifier on features
# Using the Softmax code developed earlier in the assignment, train Softmax classifiers on top of the features extracted above; this should achieve better results than training them directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from xcs231n.classifiers.linear_classifier import Softmax

learning_rates = [1e-7, 1e-6]
regularization_strengths = [5e5, 5e6]

# ### START CODE HERE ###

# ### END CODE HERE ###

results = {}
best_val = -1
best_softmax = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the Softmax; save#
# the best trained classifer in best_softmax. If you carefully tune the model, #
# you should be able to get accuracy of above 0.42 on the validation set.      #
################################################################################
# ### START CODE HERE ###
for lr in np.linspace(*learning_rates,num=60):
    for reg in np.linspace(*regularization_strengths,num=10):
        softmax = Softmax()
        _ = softmax.train(X_train_feats, y_train, learning_rate=lr, reg=reg,
                            num_iters=1_500, verbose=False)
        y_train_pred = softmax.predict(X_train_feats)
        y_val_pred = softmax.predict(X_val_feats)

        y_train_acc = np.mean(y_train_pred==y_train)
        y_val_acc = np.mean(y_val_pred==y_val)   
        results[(lr,reg)] = (y_train_acc,y_val_acc)
        if best_val < y_val_acc:
            best_val = y_val_acc
            best_softmax = softmax
# ### END CODE HERE ###

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))

print('best validation accuracy achieved: %f' % best_val)
# Out:
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.414735 val accuracy: 0.412000
# lr 1.000000e-07 reg 1.000000e+06 train accuracy: 0.412306 val accuracy: 0.423000
# lr 1.000000e-07 reg 1.500000e+06 train accuracy: 0.391306 val accuracy: 0.390000
# lr 1.000000e-07 reg 2.000000e+06 train accuracy: 0.379204 val accuracy: 0.361000
# lr 1.000000e-07 reg 2.500000e+06 train accuracy: 0.397429 val accuracy: 0.387000
# lr 1.000000e-07 reg 3.000000e+06 train accuracy: 0.387612 val accuracy: 0.390000
# lr 1.000000e-07 reg 3.500000e+06 train accuracy: 0.368755 val accuracy: 0.363000
# lr 1.000000e-07 reg 4.000000e+06 train accuracy: 0.341204 val accuracy: 0.349000
# lr 1.000000e-07 reg 4.500000e+06 train accuracy: 0.324653 val accuracy: 0.314000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.352388 val accuracy: 0.357000
# lr 1.183673e-07 reg 5.000000e+05 train accuracy: 0.417388 val accuracy: 0.420000
# lr 1.183673e-07 reg 1.000000e+06 train accuracy: 0.393449 val accuracy: 0.403000
# lr 1.183673e-07 reg 1.500000e+06 train accuracy: 0.370918 val accuracy: 0.363000
# lr 1.183673e-07 reg 2.000000e+06 train accuracy: 0.370878 val accuracy: 0.372000
# lr 1.183673e-07 reg 2.500000e+06 train accuracy: 0.370429 val accuracy: 0.387000
# lr 1.183673e-07 reg 3.000000e+06 train accuracy: 0.363286 val accuracy: 0.358000
# lr 1.183673e-07 reg 3.500000e+06 train accuracy: 0.338367 val accuracy: 0.357000
# lr 1.183673e-07 reg 4.000000e+06 train accuracy: 0.341490 val accuracy: 0.342000
# lr 1.183673e-07 reg 4.500000e+06 train accuracy: 0.306918 val accuracy: 0.293000
# lr 1.183673e-07 reg 5.000000e+06 train accuracy: 0.314245 val accuracy: 0.306000
# lr 1.367347e-07 reg 5.000000e+05 train accuracy: 0.416551 val accuracy: 0.420000
# lr 1.367347e-07 reg 1.000000e+06 train accuracy: 0.394510 val accuracy: 0.399000
# lr 1.367347e-07 reg 1.500000e+06 train accuracy: 0.391265 val accuracy: 0.403000
# lr 1.367347e-07 reg 2.000000e+06 train accuracy: 0.378878 val accuracy: 0.362000
# lr 1.367347e-07 reg 2.500000e+06 train accuracy: 0.358286 val accuracy: 0.386000
# lr 1.367347e-07 reg 3.000000e+06 train accuracy: 0.345776 val accuracy: 0.347000
# lr 1.367347e-07 reg 3.500000e+06 train accuracy: 0.319184 val accuracy: 0.316000
# lr 1.367347e-07 reg 4.000000e+06 train accuracy: 0.320469 val accuracy: 0.319000
# lr 1.367347e-07 reg 4.500000e+06 train accuracy: 0.295367 val accuracy: 0.309000
# lr 1.367347e-07 reg 5.000000e+06 train accuracy: 0.269469 val accuracy: 0.283000
# lr 1.551020e-07 reg 5.000000e+05 train accuracy: 0.390878 val accuracy: 0.394000
# lr 1.551020e-07 reg 1.000000e+06 train accuracy: 0.386959 val accuracy: 0.385000
# lr 1.551020e-07 reg 1.500000e+06 train accuracy: 0.389000 val accuracy: 0.411000
# lr 1.551020e-07 reg 2.000000e+06 train accuracy: 0.361245 val accuracy: 0.369000
# lr 1.551020e-07 reg 2.500000e+06 train accuracy: 0.334510 val accuracy: 0.336000
# lr 1.551020e-07 reg 3.000000e+06 train accuracy: 0.332612 val accuracy: 0.344000
# lr 1.551020e-07 reg 3.500000e+06 train accuracy: 0.326449 val accuracy: 0.314000
# lr 1.551020e-07 reg 4.000000e+06 train accuracy: 0.309673 val accuracy: 0.311000
# lr 1.551020e-07 reg 4.500000e+06 train accuracy: 0.297633 val accuracy: 0.297000
# lr 1.551020e-07 reg 5.000000e+06 train accuracy: 0.258776 val accuracy: 0.238000
# lr 1.734694e-07 reg 5.000000e+05 train accuracy: 0.397020 val accuracy: 0.388000
# lr 1.734694e-07 reg 1.000000e+06 train accuracy: 0.387122 val accuracy: 0.380000
# lr 1.734694e-07 reg 1.500000e+06 train accuracy: 0.393694 val accuracy: 0.389000
# lr 1.734694e-07 reg 2.000000e+06 train accuracy: 0.376551 val accuracy: 0.376000
# lr 1.734694e-07 reg 2.500000e+06 train accuracy: 0.337204 val accuracy: 0.349000
# lr 1.734694e-07 reg 3.000000e+06 train accuracy: 0.330816 val accuracy: 0.325000
# lr 1.734694e-07 reg 3.500000e+06 train accuracy: 0.318898 val accuracy: 0.311000
# lr 1.734694e-07 reg 4.000000e+06 train accuracy: 0.286531 val accuracy: 0.314000
# lr 1.734694e-07 reg 4.500000e+06 train accuracy: 0.273245 val accuracy: 0.286000
# lr 1.734694e-07 reg 5.000000e+06 train accuracy: 0.235878 val accuracy: 0.263000
# lr 1.918367e-07 reg 5.000000e+05 train accuracy: 0.401796 val accuracy: 0.399000
# lr 1.918367e-07 reg 1.000000e+06 train accuracy: 0.394878 val accuracy: 0.401000
# lr 1.918367e-07 reg 1.500000e+06 train accuracy: 0.369837 val accuracy: 0.372000
# lr 1.918367e-07 reg 2.000000e+06 train accuracy: 0.339224 val accuracy: 0.345000
# lr 1.918367e-07 reg 2.500000e+06 train accuracy: 0.330939 val accuracy: 0.330000
# lr 1.918367e-07 reg 3.000000e+06 train accuracy: 0.321469 val accuracy: 0.303000
# lr 1.918367e-07 reg 3.500000e+06 train accuracy: 0.280020 val accuracy: 0.280000
# lr 1.918367e-07 reg 4.000000e+06 train accuracy: 0.245204 val accuracy: 0.250000
# lr 1.918367e-07 reg 4.500000e+06 train accuracy: 0.261367 val accuracy: 0.285000
# lr 1.918367e-07 reg 5.000000e+06 train accuracy: 0.188918 val accuracy: 0.186000
# lr 2.102041e-07 reg 5.000000e+05 train accuracy: 0.403306 val accuracy: 0.377000
# lr 2.102041e-07 reg 1.000000e+06 train accuracy: 0.373041 val accuracy: 0.381000
# lr 2.102041e-07 reg 1.500000e+06 train accuracy: 0.356204 val accuracy: 0.341000
# lr 2.102041e-07 reg 2.000000e+06 train accuracy: 0.312388 val accuracy: 0.344000
# lr 2.102041e-07 reg 2.500000e+06 train accuracy: 0.340653 val accuracy: 0.333000
# lr 2.102041e-07 reg 3.000000e+06 train accuracy: 0.308102 val accuracy: 0.297000
# lr 2.102041e-07 reg 3.500000e+06 train accuracy: 0.264102 val accuracy: 0.260000
# lr 2.102041e-07 reg 4.000000e+06 train accuracy: 0.229694 val accuracy: 0.219000
# lr 2.102041e-07 reg 4.500000e+06 train accuracy: 0.211857 val accuracy: 0.222000
# lr 2.102041e-07 reg 5.000000e+06 train accuracy: 0.117204 val accuracy: 0.106000
# lr 2.285714e-07 reg 5.000000e+05 train accuracy: 0.396020 val accuracy: 0.398000
# lr 2.285714e-07 reg 1.000000e+06 train accuracy: 0.373633 val accuracy: 0.391000
# lr 2.285714e-07 reg 1.500000e+06 train accuracy: 0.334041 val accuracy: 0.317000
# lr 2.285714e-07 reg 2.000000e+06 train accuracy: 0.363714 val accuracy: 0.366000
# lr 2.285714e-07 reg 2.500000e+06 train accuracy: 0.325939 val accuracy: 0.340000
# lr 2.285714e-07 reg 3.000000e+06 train accuracy: 0.304735 val accuracy: 0.302000
# lr 2.285714e-07 reg 3.500000e+06 train accuracy: 0.268347 val accuracy: 0.264000
# lr 2.285714e-07 reg 4.000000e+06 train accuracy: 0.211531 val accuracy: 0.208000
# lr 2.285714e-07 reg 4.500000e+06 train accuracy: 0.113020 val accuracy: 0.117000
# lr 2.285714e-07 reg 5.000000e+06 train accuracy: 0.087429 val accuracy: 0.092000
# lr 2.469388e-07 reg 5.000000e+05 train accuracy: 0.402061 val accuracy: 0.396000
# lr 2.469388e-07 reg 1.000000e+06 train accuracy: 0.372714 val accuracy: 0.389000
# lr 2.469388e-07 reg 1.500000e+06 train accuracy: 0.356224 val accuracy: 0.365000
# lr 2.469388e-07 reg 2.000000e+06 train accuracy: 0.334449 val accuracy: 0.345000
# lr 2.469388e-07 reg 2.500000e+06 train accuracy: 0.312347 val accuracy: 0.306000
# lr 2.469388e-07 reg 3.000000e+06 train accuracy: 0.281776 val accuracy: 0.283000
# lr 2.469388e-07 reg 3.500000e+06 train accuracy: 0.231857 val accuracy: 0.247000
# lr 2.469388e-07 reg 4.000000e+06 train accuracy: 0.167878 val accuracy: 0.200000
# lr 2.469388e-07 reg 4.500000e+06 train accuracy: 0.108714 val accuracy: 0.109000
# lr 2.469388e-07 reg 5.000000e+06 train accuracy: 0.096571 val accuracy: 0.080000
# lr 2.653061e-07 reg 5.000000e+05 train accuracy: 0.411224 val accuracy: 0.420000
# lr 2.653061e-07 reg 1.000000e+06 train accuracy: 0.365776 val accuracy: 0.365000
# lr 2.653061e-07 reg 1.500000e+06 train accuracy: 0.352694 val accuracy: 0.334000
# lr 2.653061e-07 reg 2.000000e+06 train accuracy: 0.315592 val accuracy: 0.330000
# lr 2.653061e-07 reg 2.500000e+06 train accuracy: 0.290714 val accuracy: 0.287000
# lr 2.653061e-07 reg 3.000000e+06 train accuracy: 0.268755 val accuracy: 0.258000
# lr 2.653061e-07 reg 3.500000e+06 train accuracy: 0.232959 val accuracy: 0.244000
# lr 2.653061e-07 reg 4.000000e+06 train accuracy: 0.114163 val accuracy: 0.098000
# lr 2.653061e-07 reg 4.500000e+06 train accuracy: 0.091082 val accuracy: 0.088000
# lr 2.653061e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 2.836735e-07 reg 5.000000e+05 train accuracy: 0.377857 val accuracy: 0.377000
# lr 2.836735e-07 reg 1.000000e+06 train accuracy: 0.395878 val accuracy: 0.371000
# lr 2.836735e-07 reg 1.500000e+06 train accuracy: 0.358816 val accuracy: 0.343000
# lr 2.836735e-07 reg 2.000000e+06 train accuracy: 0.312163 val accuracy: 0.336000
# lr 2.836735e-07 reg 2.500000e+06 train accuracy: 0.294184 val accuracy: 0.291000
# lr 2.836735e-07 reg 3.000000e+06 train accuracy: 0.233327 val accuracy: 0.253000
# lr 2.836735e-07 reg 3.500000e+06 train accuracy: 0.106898 val accuracy: 0.101000
# lr 2.836735e-07 reg 4.000000e+06 train accuracy: 0.090163 val accuracy: 0.096000
# lr 2.836735e-07 reg 4.500000e+06 train accuracy: 0.104224 val accuracy: 0.085000
# lr 2.836735e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.020408e-07 reg 5.000000e+05 train accuracy: 0.390878 val accuracy: 0.414000
# lr 3.020408e-07 reg 1.000000e+06 train accuracy: 0.359306 val accuracy: 0.364000
# lr 3.020408e-07 reg 1.500000e+06 train accuracy: 0.317673 val accuracy: 0.328000
# lr 3.020408e-07 reg 2.000000e+06 train accuracy: 0.319571 val accuracy: 0.336000
# lr 3.020408e-07 reg 2.500000e+06 train accuracy: 0.283163 val accuracy: 0.317000
# lr 3.020408e-07 reg 3.000000e+06 train accuracy: 0.226143 val accuracy: 0.232000
# lr 3.020408e-07 reg 3.500000e+06 train accuracy: 0.082469 val accuracy: 0.081000
# lr 3.020408e-07 reg 4.000000e+06 train accuracy: 0.108878 val accuracy: 0.102000
# lr 3.020408e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.020408e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.204082e-07 reg 5.000000e+05 train accuracy: 0.399673 val accuracy: 0.409000
# lr 3.204082e-07 reg 1.000000e+06 train accuracy: 0.370673 val accuracy: 0.394000
# lr 3.204082e-07 reg 1.500000e+06 train accuracy: 0.336837 val accuracy: 0.301000
# lr 3.204082e-07 reg 2.000000e+06 train accuracy: 0.300918 val accuracy: 0.314000
# lr 3.204082e-07 reg 2.500000e+06 train accuracy: 0.251918 val accuracy: 0.221000
# lr 3.204082e-07 reg 3.000000e+06 train accuracy: 0.161776 val accuracy: 0.151000
# lr 3.204082e-07 reg 3.500000e+06 train accuracy: 0.107735 val accuracy: 0.097000
# lr 3.204082e-07 reg 4.000000e+06 train accuracy: 0.121755 val accuracy: 0.112000
# lr 3.204082e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.204082e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.387755e-07 reg 5.000000e+05 train accuracy: 0.373939 val accuracy: 0.389000
# lr 3.387755e-07 reg 1.000000e+06 train accuracy: 0.352959 val accuracy: 0.354000
# lr 3.387755e-07 reg 1.500000e+06 train accuracy: 0.301388 val accuracy: 0.308000
# lr 3.387755e-07 reg 2.000000e+06 train accuracy: 0.289592 val accuracy: 0.268000
# lr 3.387755e-07 reg 2.500000e+06 train accuracy: 0.260367 val accuracy: 0.278000
# lr 3.387755e-07 reg 3.000000e+06 train accuracy: 0.094327 val accuracy: 0.086000
# lr 3.387755e-07 reg 3.500000e+06 train accuracy: 0.096388 val accuracy: 0.094000
# lr 3.387755e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.387755e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.387755e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.571429e-07 reg 5.000000e+05 train accuracy: 0.389592 val accuracy: 0.410000
# lr 3.571429e-07 reg 1.000000e+06 train accuracy: 0.348571 val accuracy: 0.348000
# lr 3.571429e-07 reg 1.500000e+06 train accuracy: 0.323041 val accuracy: 0.341000
# lr 3.571429e-07 reg 2.000000e+06 train accuracy: 0.259571 val accuracy: 0.240000
# lr 3.571429e-07 reg 2.500000e+06 train accuracy: 0.237939 val accuracy: 0.258000
# lr 3.571429e-07 reg 3.000000e+06 train accuracy: 0.091020 val accuracy: 0.089000
# lr 3.571429e-07 reg 3.500000e+06 train accuracy: 0.116592 val accuracy: 0.109000
# lr 3.571429e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.571429e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.571429e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.755102e-07 reg 5.000000e+05 train accuracy: 0.385490 val accuracy: 0.381000
# lr 3.755102e-07 reg 1.000000e+06 train accuracy: 0.362306 val accuracy: 0.358000
# lr 3.755102e-07 reg 1.500000e+06 train accuracy: 0.336347 val accuracy: 0.349000
# lr 3.755102e-07 reg 2.000000e+06 train accuracy: 0.268612 val accuracy: 0.276000
# lr 3.755102e-07 reg 2.500000e+06 train accuracy: 0.215245 val accuracy: 0.209000
# lr 3.755102e-07 reg 3.000000e+06 train accuracy: 0.100714 val accuracy: 0.113000
# lr 3.755102e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.755102e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.755102e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.755102e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.938776e-07 reg 5.000000e+05 train accuracy: 0.394265 val accuracy: 0.413000
# lr 3.938776e-07 reg 1.000000e+06 train accuracy: 0.354714 val accuracy: 0.371000
# lr 3.938776e-07 reg 1.500000e+06 train accuracy: 0.296000 val accuracy: 0.288000
# lr 3.938776e-07 reg 2.000000e+06 train accuracy: 0.266551 val accuracy: 0.267000
# lr 3.938776e-07 reg 2.500000e+06 train accuracy: 0.164673 val accuracy: 0.140000
# lr 3.938776e-07 reg 3.000000e+06 train accuracy: 0.095694 val accuracy: 0.095000
# lr 3.938776e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.938776e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.938776e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 3.938776e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.122449e-07 reg 5.000000e+05 train accuracy: 0.363000 val accuracy: 0.354000
# lr 4.122449e-07 reg 1.000000e+06 train accuracy: 0.328265 val accuracy: 0.312000
# lr 4.122449e-07 reg 1.500000e+06 train accuracy: 0.280265 val accuracy: 0.288000
# lr 4.122449e-07 reg 2.000000e+06 train accuracy: 0.246714 val accuracy: 0.251000
# lr 4.122449e-07 reg 2.500000e+06 train accuracy: 0.093837 val accuracy: 0.108000
# lr 4.122449e-07 reg 3.000000e+06 train accuracy: 0.112184 val accuracy: 0.098000
# lr 4.122449e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.122449e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.122449e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.122449e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.306122e-07 reg 5.000000e+05 train accuracy: 0.392122 val accuracy: 0.413000
# lr 4.306122e-07 reg 1.000000e+06 train accuracy: 0.346510 val accuracy: 0.341000
# lr 4.306122e-07 reg 1.500000e+06 train accuracy: 0.296204 val accuracy: 0.312000
# lr 4.306122e-07 reg 2.000000e+06 train accuracy: 0.233449 val accuracy: 0.245000
# lr 4.306122e-07 reg 2.500000e+06 train accuracy: 0.104796 val accuracy: 0.120000
# lr 4.306122e-07 reg 3.000000e+06 train accuracy: 0.094184 val accuracy: 0.095000
# lr 4.306122e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.306122e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.306122e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.306122e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.489796e-07 reg 5.000000e+05 train accuracy: 0.385245 val accuracy: 0.375000
# lr 4.489796e-07 reg 1.000000e+06 train accuracy: 0.335837 val accuracy: 0.354000
# lr 4.489796e-07 reg 1.500000e+06 train accuracy: 0.281939 val accuracy: 0.299000
# lr 4.489796e-07 reg 2.000000e+06 train accuracy: 0.204510 val accuracy: 0.189000
# lr 4.489796e-07 reg 2.500000e+06 train accuracy: 0.111184 val accuracy: 0.101000
# lr 4.489796e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.489796e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.489796e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.489796e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.489796e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.673469e-07 reg 5.000000e+05 train accuracy: 0.386163 val accuracy: 0.399000
# lr 4.673469e-07 reg 1.000000e+06 train accuracy: 0.338204 val accuracy: 0.326000
# lr 4.673469e-07 reg 1.500000e+06 train accuracy: 0.292898 val accuracy: 0.286000
# lr 4.673469e-07 reg 2.000000e+06 train accuracy: 0.241673 val accuracy: 0.219000
# lr 4.673469e-07 reg 2.500000e+06 train accuracy: 0.094592 val accuracy: 0.081000
# lr 4.673469e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.673469e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.673469e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.673469e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.673469e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.857143e-07 reg 5.000000e+05 train accuracy: 0.374306 val accuracy: 0.374000
# lr 4.857143e-07 reg 1.000000e+06 train accuracy: 0.314327 val accuracy: 0.319000
# lr 4.857143e-07 reg 1.500000e+06 train accuracy: 0.291041 val accuracy: 0.300000
# lr 4.857143e-07 reg 2.000000e+06 train accuracy: 0.195020 val accuracy: 0.187000
# lr 4.857143e-07 reg 2.500000e+06 train accuracy: 0.095837 val accuracy: 0.096000
# lr 4.857143e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.857143e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.857143e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.857143e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 4.857143e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.040816e-07 reg 5.000000e+05 train accuracy: 0.365694 val accuracy: 0.358000
# lr 5.040816e-07 reg 1.000000e+06 train accuracy: 0.314184 val accuracy: 0.322000
# lr 5.040816e-07 reg 1.500000e+06 train accuracy: 0.257714 val accuracy: 0.273000
# lr 5.040816e-07 reg 2.000000e+06 train accuracy: 0.091000 val accuracy: 0.097000
# lr 5.040816e-07 reg 2.500000e+06 train accuracy: 0.153143 val accuracy: 0.161000
# lr 5.040816e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.040816e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.040816e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.040816e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.040816e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.224490e-07 reg 5.000000e+05 train accuracy: 0.368592 val accuracy: 0.355000
# lr 5.224490e-07 reg 1.000000e+06 train accuracy: 0.346510 val accuracy: 0.371000
# lr 5.224490e-07 reg 1.500000e+06 train accuracy: 0.240061 val accuracy: 0.220000
# lr 5.224490e-07 reg 2.000000e+06 train accuracy: 0.103020 val accuracy: 0.110000
# lr 5.224490e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.224490e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.224490e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.224490e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.224490e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.224490e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.408163e-07 reg 5.000000e+05 train accuracy: 0.364347 val accuracy: 0.350000
# lr 5.408163e-07 reg 1.000000e+06 train accuracy: 0.312204 val accuracy: 0.302000
# lr 5.408163e-07 reg 1.500000e+06 train accuracy: 0.246347 val accuracy: 0.239000
# lr 5.408163e-07 reg 2.000000e+06 train accuracy: 0.087102 val accuracy: 0.082000
# lr 5.408163e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.408163e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.408163e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.408163e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.408163e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.408163e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.591837e-07 reg 5.000000e+05 train accuracy: 0.367918 val accuracy: 0.383000
# lr 5.591837e-07 reg 1.000000e+06 train accuracy: 0.288939 val accuracy: 0.288000
# lr 5.591837e-07 reg 1.500000e+06 train accuracy: 0.259224 val accuracy: 0.286000
# lr 5.591837e-07 reg 2.000000e+06 train accuracy: 0.110306 val accuracy: 0.087000
# lr 5.591837e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.591837e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.591837e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.591837e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.591837e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.591837e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.775510e-07 reg 5.000000e+05 train accuracy: 0.368245 val accuracy: 0.355000
# lr 5.775510e-07 reg 1.000000e+06 train accuracy: 0.306082 val accuracy: 0.293000
# lr 5.775510e-07 reg 1.500000e+06 train accuracy: 0.244449 val accuracy: 0.246000
# lr 5.775510e-07 reg 2.000000e+06 train accuracy: 0.106776 val accuracy: 0.123000
# lr 5.775510e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.775510e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.775510e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.775510e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.775510e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.775510e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.959184e-07 reg 5.000000e+05 train accuracy: 0.390408 val accuracy: 0.394000
# lr 5.959184e-07 reg 1.000000e+06 train accuracy: 0.313735 val accuracy: 0.328000
# lr 5.959184e-07 reg 1.500000e+06 train accuracy: 0.232694 val accuracy: 0.246000
# lr 5.959184e-07 reg 2.000000e+06 train accuracy: 0.118327 val accuracy: 0.101000
# lr 5.959184e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.959184e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.959184e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.959184e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.959184e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.959184e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.142857e-07 reg 5.000000e+05 train accuracy: 0.369245 val accuracy: 0.363000
# lr 6.142857e-07 reg 1.000000e+06 train accuracy: 0.307878 val accuracy: 0.305000
# lr 6.142857e-07 reg 1.500000e+06 train accuracy: 0.207531 val accuracy: 0.217000
# lr 6.142857e-07 reg 2.000000e+06 train accuracy: 0.096531 val accuracy: 0.109000
# lr 6.142857e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.142857e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.142857e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.142857e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.142857e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.142857e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.326531e-07 reg 5.000000e+05 train accuracy: 0.363510 val accuracy: 0.389000
# lr 6.326531e-07 reg 1.000000e+06 train accuracy: 0.309694 val accuracy: 0.313000
# lr 6.326531e-07 reg 1.500000e+06 train accuracy: 0.235449 val accuracy: 0.240000
# lr 6.326531e-07 reg 2.000000e+06 train accuracy: 0.100980 val accuracy: 0.109000
# lr 6.326531e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.326531e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.326531e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.326531e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.326531e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.326531e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.510204e-07 reg 5.000000e+05 train accuracy: 0.351490 val accuracy: 0.320000
# lr 6.510204e-07 reg 1.000000e+06 train accuracy: 0.315143 val accuracy: 0.316000
# lr 6.510204e-07 reg 1.500000e+06 train accuracy: 0.156082 val accuracy: 0.168000
# lr 6.510204e-07 reg 2.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.510204e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.510204e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.510204e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.510204e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.510204e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.510204e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.693878e-07 reg 5.000000e+05 train accuracy: 0.353551 val accuracy: 0.344000
# lr 6.693878e-07 reg 1.000000e+06 train accuracy: 0.295388 val accuracy: 0.310000
# lr 6.693878e-07 reg 1.500000e+06 train accuracy: 0.108551 val accuracy: 0.106000
# lr 6.693878e-07 reg 2.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.693878e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.693878e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.693878e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.693878e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.693878e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.693878e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.877551e-07 reg 5.000000e+05 train accuracy: 0.369857 val accuracy: 0.379000
# lr 6.877551e-07 reg 1.000000e+06 train accuracy: 0.293673 val accuracy: 0.281000
# lr 6.877551e-07 reg 1.500000e+06 train accuracy: 0.110939 val accuracy: 0.107000
# lr 6.877551e-07 reg 2.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.877551e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.877551e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.877551e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.877551e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.877551e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 6.877551e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.061224e-07 reg 5.000000e+05 train accuracy: 0.366592 val accuracy: 0.377000
# lr 7.061224e-07 reg 1.000000e+06 train accuracy: 0.290000 val accuracy: 0.297000
# lr 7.061224e-07 reg 1.500000e+06 train accuracy: 0.107000 val accuracy: 0.123000
# lr 7.061224e-07 reg 2.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.061224e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.061224e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.061224e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.061224e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.061224e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.061224e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.244898e-07 reg 5.000000e+05 train accuracy: 0.352898 val accuracy: 0.347000
# lr 7.244898e-07 reg 1.000000e+06 train accuracy: 0.271061 val accuracy: 0.283000
# lr 7.244898e-07 reg 1.500000e+06 train accuracy: 0.086551 val accuracy: 0.093000
# lr 7.244898e-07 reg 2.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.244898e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.244898e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.244898e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.244898e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.244898e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.244898e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.428571e-07 reg 5.000000e+05 train accuracy: 0.370408 val accuracy: 0.399000
# lr 7.428571e-07 reg 1.000000e+06 train accuracy: 0.256612 val accuracy: 0.265000
# lr 7.428571e-07 reg 1.500000e+06 train accuracy: 0.084469 val accuracy: 0.085000
# lr 7.428571e-07 reg 2.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.428571e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.428571e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.428571e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.428571e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.428571e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.428571e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.612245e-07 reg 5.000000e+05 train accuracy: 0.331551 val accuracy: 0.333000
# lr 7.612245e-07 reg 1.000000e+06 train accuracy: 0.275245 val accuracy: 0.266000
# lr 7.612245e-07 reg 1.500000e+06 train accuracy: 0.084959 val accuracy: 0.099000
# lr 7.612245e-07 reg 2.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.612245e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.612245e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.612245e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.612245e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.612245e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.612245e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.795918e-07 reg 5.000000e+05 train accuracy: 0.338796 val accuracy: 0.369000
# lr 7.795918e-07 reg 1.000000e+06 train accuracy: 0.259878 val accuracy: 0.256000
# lr 7.795918e-07 reg 1.500000e+06 train accuracy: 0.095816 val accuracy: 0.103000
# lr 7.795918e-07 reg 2.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.795918e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.795918e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.795918e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.795918e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.795918e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.795918e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.979592e-07 reg 5.000000e+05 train accuracy: 0.348327 val accuracy: 0.365000
# lr 7.979592e-07 reg 1.000000e+06 train accuracy: 0.230347 val accuracy: 0.255000
# lr 7.979592e-07 reg 1.500000e+06 train accuracy: 0.091571 val accuracy: 0.084000
# lr 7.979592e-07 reg 2.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.979592e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.979592e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.979592e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.979592e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.979592e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 7.979592e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.163265e-07 reg 5.000000e+05 train accuracy: 0.334429 val accuracy: 0.338000
# lr 8.163265e-07 reg 1.000000e+06 train accuracy: 0.264837 val accuracy: 0.248000
# lr 8.163265e-07 reg 1.500000e+06 train accuracy: 0.091612 val accuracy: 0.088000
# lr 8.163265e-07 reg 2.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.163265e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.163265e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.163265e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.163265e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.163265e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.163265e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.346939e-07 reg 5.000000e+05 train accuracy: 0.342918 val accuracy: 0.345000
# lr 8.346939e-07 reg 1.000000e+06 train accuracy: 0.228551 val accuracy: 0.247000
# lr 8.346939e-07 reg 1.500000e+06 train accuracy: 0.105245 val accuracy: 0.113000
# lr 8.346939e-07 reg 2.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.346939e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.346939e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.346939e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.346939e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.346939e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.346939e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.530612e-07 reg 5.000000e+05 train accuracy: 0.327122 val accuracy: 0.337000
# lr 8.530612e-07 reg 1.000000e+06 train accuracy: 0.240592 val accuracy: 0.223000
# lr 8.530612e-07 reg 1.500000e+06 train accuracy: 0.097000 val accuracy: 0.098000
# lr 8.530612e-07 reg 2.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.530612e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.530612e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.530612e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.530612e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.530612e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.530612e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.714286e-07 reg 5.000000e+05 train accuracy: 0.326408 val accuracy: 0.298000
# lr 8.714286e-07 reg 1.000000e+06 train accuracy: 0.243959 val accuracy: 0.253000
# lr 8.714286e-07 reg 1.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.714286e-07 reg 2.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.714286e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.714286e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.714286e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.714286e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.714286e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.714286e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.897959e-07 reg 5.000000e+05 train accuracy: 0.331367 val accuracy: 0.327000
# lr 8.897959e-07 reg 1.000000e+06 train accuracy: 0.258041 val accuracy: 0.302000
# lr 8.897959e-07 reg 1.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.897959e-07 reg 2.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.897959e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.897959e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.897959e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.897959e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.897959e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 8.897959e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.081633e-07 reg 5.000000e+05 train accuracy: 0.340061 val accuracy: 0.339000
# lr 9.081633e-07 reg 1.000000e+06 train accuracy: 0.212571 val accuracy: 0.232000
# lr 9.081633e-07 reg 1.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.081633e-07 reg 2.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.081633e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.081633e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.081633e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.081633e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.081633e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.081633e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.265306e-07 reg 5.000000e+05 train accuracy: 0.344776 val accuracy: 0.339000
# lr 9.265306e-07 reg 1.000000e+06 train accuracy: 0.245163 val accuracy: 0.269000
# lr 9.265306e-07 reg 1.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.265306e-07 reg 2.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.265306e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.265306e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.265306e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.265306e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.265306e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.265306e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.448980e-07 reg 5.000000e+05 train accuracy: 0.323898 val accuracy: 0.334000
# lr 9.448980e-07 reg 1.000000e+06 train accuracy: 0.210204 val accuracy: 0.225000
# lr 9.448980e-07 reg 1.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.448980e-07 reg 2.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.448980e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.448980e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.448980e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.448980e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.448980e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.448980e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.632653e-07 reg 5.000000e+05 train accuracy: 0.314714 val accuracy: 0.308000
# lr 9.632653e-07 reg 1.000000e+06 train accuracy: 0.170204 val accuracy: 0.169000
# lr 9.632653e-07 reg 1.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.632653e-07 reg 2.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.632653e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.632653e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.632653e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.632653e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.632653e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.632653e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.816327e-07 reg 5.000000e+05 train accuracy: 0.315510 val accuracy: 0.319000
# lr 9.816327e-07 reg 1.000000e+06 train accuracy: 0.152857 val accuracy: 0.158000
# lr 9.816327e-07 reg 1.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.816327e-07 reg 2.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.816327e-07 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.816327e-07 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.816327e-07 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.816327e-07 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.816327e-07 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 9.816327e-07 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-06 reg 5.000000e+05 train accuracy: 0.330184 val accuracy: 0.335000
# lr 1.000000e-06 reg 1.000000e+06 train accuracy: 0.092980 val accuracy: 0.102000
# lr 1.000000e-06 reg 1.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-06 reg 2.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-06 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-06 reg 3.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-06 reg 3.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-06 reg 4.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-06 reg 4.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-06 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved: 0.423000

# %%
# Evaluate your trained Softmax on the test set: you should be able to get at least 0.42
y_test_pred = best_softmax.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.412

# %%
# Save best softmax model
best_softmax.save("best_softmax_features.npy")
# Out:
# best_softmax_features.npy saved.

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
#
# $\color{blue}{\textit Your Answer:}$
#
# ### START ANSWER HERE ###
# Some misclassifications make sense because the images have similar shapes or visual characteristics. For example, a truck may be misclassified as a car. However, some misclassifications are less intuitive, such as a plane being classified as a frog.
# ### END ANSWER HERE ###

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 169)
# (49000, 168)

# %%
from xcs231n.classifiers.fc_net import TwoLayerNet
from xcs231n.solver import Solver

input_dim = X_train_feats.shape[1]
hidden_dim = 500
num_classes = 10

data = {
    'X_train': X_train_feats,
    'y_train': y_train,
    'X_val': X_val_feats,
    'y_val': y_val,
    'X_test': X_test_feats,
    'y_test': y_test,
}

net = TwoLayerNet(input_dim, hidden_dim, num_classes)
best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# ### START CODE HERE ###
from sklearn.model_selection import ParameterSampler

rng = np.random.default_rng(42)
param_dist = {
    "learning_rate": 10 ** rng.uniform(-4, -1, 200),
    "reg": 10 ** rng.uniform(-4, 1, 200),
    "weight_scale": 10 ** rng.uniform(-3, -1, 200),
}

params = ParameterSampler(param_dist,n_iter=20,random_state=42)

search_epochs = 10

best_val_acc = -1
best_hyperparams = {}

for p in params:
    lr = p["learning_rate"]
    reg = p["reg"]
    weight_scale = p["weight_scale"]

    model = TwoLayerNet(
        input_dim=input_dim,
        hidden_dim=hidden_dim,
        num_classes=num_classes,
        weight_scale=weight_scale,
        reg=reg
    )

    solver = Solver(model,data,
                update_rule="sgd",
                optim_config={
                    "learning_rate": lr,
                },
                num_epochs=search_epochs,
                lr_decay=0.95,
                batch_size=200,
                num_val_samples=1000,
                print_every=1000,
                verbose=False
            )

    solver.train()
    val_acc = solver.best_val_acc

    print(f"lr={lr:.2e}, reg={reg:.2e}, weight_scale={weight_scale:.2e} ----> val_acc={val_acc:.4f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_net = model

        best_hyperparams = {
            "lr": lr,
            "reg": reg,
            "weight_scale": weight_scale
        }

finetune_epoch = 50

lr = best_hyperparams["lr"]
reg = best_hyperparams["reg"]
weight_scale = best_hyperparams["weight_scale"]

model = TwoLayerNet(
    input_dim=input_dim,
    hidden_dim=hidden_dim,
    num_classes=num_classes,
    weight_scale=weight_scale,
    reg=reg
)

solver = Solver(model,data,
            update_rule="sgd",
            optim_config={
                "learning_rate": lr,
            },
            num_epochs=finetune_epoch,
            lr_decay=0.95,
            batch_size=200,
            num_val_samples=1000,
            print_every=1000,
            verbose=False
        )

solver.train()
val_acc = solver.best_val_acc

print(f"lr={lr:.2e}, reg={reg:.2e}, weight_scale={weight_scale:.2e} ----> val_acc={val_acc:.4f}")


best_val_acc = val_acc
best_net = model


print("Best hyperparameters:")
print(best_hyperparams)
print("Best validation accuracy:", best_val_acc)

# ### END CODE HERE ###
# Out:
# lr=2.10e-04, reg=5.86e-04, weight_scale=1.14e-03 ----> val_acc=0.1570
# lr=3.12e-04, reg=1.05e+00, weight_scale=2.00e-02 ----> val_acc=0.2110
# lr=2.10e-04, reg=7.89e-03, weight_scale=2.42e-03 ----> val_acc=0.1850
# lr=2.33e-04, reg=2.76e-03, weight_scale=6.43e-03 ----> val_acc=0.1940
# lr=1.29e-04, reg=7.28e-02, weight_scale=1.20e-03 ----> val_acc=0.1090
# lr=1.26e-02, reg=5.24e-04, weight_scale=9.56e-02 ----> val_acc=0.5070
# lr=6.56e-04, reg=4.38e-03, weight_scale=9.23e-03 ----> val_acc=0.2910
# lr=1.77e-03, reg=6.78e+00, weight_scale=1.18e-03 ----> val_acc=0.1180
# lr=2.07e-02, reg=6.14e-04, weight_scale=1.07e-03 ----> val_acc=0.5050
# lr=2.20e-02, reg=6.62e-03, weight_scale=1.35e-02 ----> val_acc=0.5310
# lr=3.60e-03, reg=1.21e+00, weight_scale=6.10e-03 ----> val_acc=0.1500
# lr=1.02e-02, reg=1.82e-01, weight_scale=3.70e-03 ----> val_acc=0.2670
# lr=2.12e-04, reg=5.70e+00, weight_scale=5.02e-02 ----> val_acc=0.1980
# lr=2.90e-04, reg=1.65e-04, weight_scale=3.60e-03 ----> val_acc=0.1770
# lr=1.26e-02, reg=2.71e-03, weight_scale=2.83e-03 ----> val_acc=0.4600
# lr=4.70e-02, reg=2.77e-02, weight_scale=1.52e-03 ----> val_acc=0.5210
# lr=5.60e-02, reg=2.01e+00, weight_scale=1.87e-02 ----> val_acc=0.1220
# lr=1.72e-02, reg=1.63e-02, weight_scale=4.83e-02 ----> val_acc=0.5310
# lr=4.05e-04, reg=3.85e-04, weight_scale=8.88e-03 ----> val_acc=0.2420
# lr=9.88e-03, reg=1.82e-04, weight_scale=2.95e-02 ----> val_acc=0.5190
# lr=2.20e-02, reg=6.62e-03, weight_scale=1.35e-02 ----> val_acc=0.5480
# Best hyperparameters:
# {'lr': np.float64(0.02198806909748976), 'reg': np.float64(0.00662155649599039), 'weight_scale': np.float64(0.013537666182114683)}
# Best validation accuracy: 0.548

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 58% accuracy. It is also possible to get >60% accuracy
# with careful tuning.

y_test_pred = np.argmax(best_net.loss(data['X_test']), axis=1)
test_acc = (y_test_pred == data['y_test']).mean()
print(test_acc)
# Out:
# 0.529

# %%
# Save best model
best_net.save("best_two_layer_net_features.npy")
# Out:
# best_two_layer_net_features.npy saved.

# %%
for k, v in best_net.params.items():
  print(k, v.shape)
print(X_train_feats.shape)
print(best_softmax.W.shape)
# Out:
# W1 (168, 500)
# b1 (500,)
# W2 (500, 10)
# b2 (10,)
# (49000, 168)
# (169, 10)

# %% [markdown]
# # Submission
#
# **You will need to submit the answers from this notebook on Gradescope.**
